# %%
import numpy as np
import pandas as pd
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\elena\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
def read_corpus():
    sentences = np.concatenate((pd.read_table('data/multinli_dev_set.txt')['sentence1'].get_values(),
                                pd.read_table('data/multinli_dev_set.txt')['sentence2'].get_values()))

    labels = np.concatenate((pd.read_table('data/multinli_dev_set.txt')['genre'].get_values(),
                             pd.read_table('data/multinli_dev_set.txt')['genre'].get_values()))

    return sentences, labels

# %%
sentences, labels = read_corpus()
# Out:
# C:\Users\elena\PycharmProjects\NLP_Lab01\venv\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: The 'get_values' method is deprecated and will be removed in a future version. Use '.to_numpy()' or '.array' instead.
#
# C:\Users\elena\PycharmProjects\NLP_Lab01\venv\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: The 'get_values' method is deprecated and will be removed in a future version. Use '.to_numpy()' or '.array' instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\elena\PycharmProjects\NLP_Lab01\venv\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: The 'get_values' method is deprecated and will be removed in a future version. Use '.to_numpy()' or '.array' instead.
#   """
# C:\Users\elena\PycharmProjects\NLP_Lab01\venv\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: The 'get_values' method is deprecated and will be removed in a future version. Use '.to_numpy()' or '.array' instead.

# %%
flat_words_nonunique = []
for sentence in sentences:
    flat_words_nonunique.append(nltk.word_tokenize(sentence.lower()))
flat_words_nonunique = np.concatenate(flat_words_nonunique).ravel()
flat_words_nonunique
# Out:
# array(['the', 'new', 'rights', ..., 'bother', 'listening', '.'],
#       dtype='<U45')

# %%
flat_words = np.unique(flat_words_nonunique)
flat_words
# Out:
# array(['!', '$', '%', ..., 'υrt', '”', '…'], dtype='<U45')

# %%
# Primitive approach using numpy functions
frequency = dict() 
for word in flat_words:
    frequency[word] = flat_words_nonunique.tolist().count(word)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-bdf82ea33319> in <module>
#       2 frequency = dict()
#       3 for word in flat_words:
# ----> 4     frequency[word] = flat_words_nonunique.tolist().count(word)
#
# KeyboardInterrupt:

# %%
frequency = nltk.probability.FreqDist(flat_words_nonunique)
frequency

# %%
import matplotlib.pyplot as plt

# %%
first2pairs = {k: frequency[k] for k in list(frequency)[:20]}

# %%
sorted_x = sorted(first2pairs.items(), key=lambda kv: kv[1], reverse=True)

x, y = zip(*sorted_x)
plt.plot(x, y)

# %%
lists = sorted(first2pairs.items()) # sorted by key, return a list of tuples

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
stopwords.words('english')

# %%
non_working_words = [x for x in flat_words if x not in stopwords.words('english')]
len(non_working_words)
non_working_words

# %%
    from nltk.tokenize import RegexpTokenizer
    tokenizer = RegexpTokenizer(r'\w+')
    sentences, labels = read_corpus()
    flat_words_nonunique = []
    for sentence in sentences:
        # This tokenizer allows for punctiation to remain
        flat_words_nonunique.append(tokenizer.tokenize(sentence.lower()))
    flat_words_nonunique = np.concatenate(flat_words_nonunique).ravel()

# %%
flat_words_noww = [x for x in flat_words_nonunique if x not in stopwords.words('english')]
freq = nltk.probability.FreqDist(flat_words_noww)
freq

# %%
k=500
list_minus_k = {}
for i in freq:
    if freq[i]>k:
        list_minus_k[i] = freq[i]

sorted_x = sorted(list_minus_k.items(), key=lambda kv: kv[1], reverse=True)

x, y = zip(*sorted_x)
plt.plot(x, y)

# %%
tokenizer = RegexpTokenizer(r'\w+')
sentences, labels = read_corpus()
flat_words_nonunique = []
for sentence in sentences:
        # This tokenizer allows for punctiation to remain
    flat_words_nonunique.append(tokenizer.tokenize(sentence.lower()))
flat_words_nonunique = np.concatenate(flat_words_nonunique).ravel()
flat_words_noww = [x for x in flat_words_nonunique if x not in stopwords.words('english')]

stemmed_words = []

from nltk.stem import PorterStemmer
stemmer = PorterStemmer()

# %%
for word in flat_words_noww:
        stemmed_words.append(stemmer.stem(word))
        
stemmed_words = list(np.unique(stemmed_words))

# %%
freq = nltk.probability.FreqDist(stemmed_words)
stemmed_words

# %%
first20pairs = {k: freq[k] for k in list(freq)[:20]}
first20pairs
sorted_x = sorted(first20pairs.items(), key=lambda kv: kv[1], Reverse=True)  # Sorted in reverse so we have the most frequent words
x, y = zip(*sorted_x)  # Separating in two lists
plt.plot(x, y)
plt.show()

# %%
tokenizer = RegexpTokenizer(r'\w+')
sentences, labels = read_corpus()
flat_words_nonunique = []
for sentence in sentences:
    # This tokenizer allows for punctiation to remain
    flat_words_nonunique.append(tokenizer.tokenize(sentence.lower()))
flat_words_nonunique = np.concatenate(flat_words_nonunique).ravel()
flat_words_noww = [x for x in flat_words_nonunique if x not in stopwords.words('english')]
stemmed_words = []
stemmer = PorterStemmer()
for word in flat_words_noww:
    stemmed_words.append(stemmer.stem(word))

stemmed_words = list(stemmed_words)
stemmed_words

# %%
frequency = nltk.probability.FreqDist(stemmed_words)  # Returns tuples of word : frequency

k=10
list_minus_k = {}
for i in freq:
    if freq[i] > k:
        list_minus_k[i] = freq[i]

# %%
sorted_x = sorted(list_minus_k.items(), key=lambda kv: kv[1], reverse=True)

x, y = zip(*sorted_x)
plt.plot(x, y)

# %%
list_minus_k = {}
    for i in freq:
        if freq[i] > k:
            list_minus_k[i] = freq[i]

    sorted_x = sorted(list_minus_k.items(), key=lambda kv: kv[1], reverse=True)

    x, y = zip(*sorted_x)
    plt.plot(x, y)

# %% [markdown]
# Trying stuff out

# %%
pip install sklearn
# Out:
# Requirement already satisfied: sklearn in c:\users\elena\pycharmprojects\nlp_lab01\venv\lib\site-packages (0.0)
# Requirement already satisfied: scikit-learn in c:\users\elena\pycharmprojects\nlp_lab01\venv\lib\site-packages (from sklearn) (0.21.3)
# Requirement already satisfied: numpy>=1.11.0 in c:\users\elena\pycharmprojects\nlp_lab01\venv\lib\site-packages (from scikit-learn->sklearn) (1.17.3)
# Requirement already satisfied: scipy>=0.17.0 in c:\users\elena\pycharmprojects\nlp_lab01\venv\lib\site-packages (from scikit-learn->sklearn) (1.3.1)
# Requirement already satisfied: joblib>=0.11 in c:\users\elena\pycharmprojects\nlp_lab01\venv\lib\site-packages (from scikit-learn->sklearn) (0.14.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 19.2.3, however version 19.3.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
sentences, labels = read_corpus()
# Out:
# C:\Users\elena\PycharmProjects\NLP_Lab01\venv\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: The 'get_values' method is deprecated and will be removed in a future version. Use '.to_numpy()' or '.array' instead.
#
# C:\Users\elena\PycharmProjects\NLP_Lab01\venv\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: The 'get_values' method is deprecated and will be removed in a future version. Use '.to_numpy()' or '.array' instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\elena\PycharmProjects\NLP_Lab01\venv\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: The 'get_values' method is deprecated and will be removed in a future version. Use '.to_numpy()' or '.array' instead.
#   """
# C:\Users\elena\PycharmProjects\NLP_Lab01\venv\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: The 'get_values' method is deprecated and will be removed in a future version. Use '.to_numpy()' or '.array' instead.

# %%
len(sentences)
n = np.unique(labels)
n
# Out:
# array(['fiction', 'government', 'slate', 'telephone', 'travel'],
#       dtype=object)

# %%
from sklearn.model_selection import train_test_split

X = sentences
y = labels
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
print(f'Training set: {len(X_train)} with {len(y_train)} labels')
print(f'Testing set: {len(X_test)} with {len(y_test)} labels')
# Out:
# Training set: 15835 with 15835 labels
# Testing set: 3959 with 3959 labels

# %%
df = pd.DataFrame(data={'text':sentences, "label":labels})
df.head()
# Out:
#                                                 text       label
# 0                     The new rights are nice enough       slate
# 1  This site includes a list of all award winners...  government
# 2  uh i don't know i i have mixed emotions about ...   telephone
# 3  yeah i i think my favorite restaurant is alway...   telephone
# 4         i don't know um do you do a lot of camping   telephone

# %%
pip install spacy
# Out:
# Requirement already satisfied: spacy in c:\users\elena\pycharmprojects\nlp_lab01\venv\lib\site-packages (2.2.1)
# Requirement already satisfied: srsly<1.1.0,>=0.1.0 in c:\users\elena\pycharmprojects\nlp_lab01\venv\lib\site-packages (from spacy) (0.2.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in c:\users\elena\pycharmprojects\nlp_lab01\venv\lib\site-packages (from spacy) (0.4.1)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\elena\pycharmprojects\nlp_lab01\venv\lib\site-packages (from spacy) (1.17.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\elena\pycharmprojects\nlp_lab01\venv\lib\site-packages (from spacy) (2.22.0)
# Requirement already satisfied: plac<1.0.0,>=0.9.6 in c:\users\elena\pycharmprojects\nlp_lab01\venv\lib\site-packages (from spacy) (0.9.6)
# Requirement already satisfied: thinc<7.2.0,>=7.1.1 in c:\users\elena\pycharmprojects\nlp_lab01\venv\lib\site-packages (from spacy) (7.1.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\elena\pycharmprojects\nlp_lab01\venv\lib\site-packages (from spacy) (3.0.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\elena\pycharmprojects\nlp_lab01\venv\lib\site-packages (from spacy) (1.0.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.2.0 in c:\users\elena\pycharmprojects\nlp_lab01\venv\lib\site-packages (from spacy) (0.3.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\elena\pycharmprojects\nlp_lab01\venv\lib\site-packages (from spacy) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\elena\pycharmprojects\nlp_lab01\venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2019.9.11)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\elena\pycharmprojects\nlp_lab01\venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\elena\pycharmprojects\nlp_lab01\venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\elena\pycharmprojects\nlp_lab01\venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.25.6)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in c:\users\elena\pycharmprojects\nlp_lab01\venv\lib\site-packages (from thinc<7.2.0,>=7.1.1->spacy) (4.36.1)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 19.2.3, however version 19.3.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import sys
np.set_printoptions(threshold=sys.maxsize)
from sklearn.feature_extraction.text import CountVectorizer

# %%
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(sentences)
print(X.toarray())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-df65e6fcbf10> in <module>
#       1 vectorizer = CountVectorizer()
#       2 X = vectorizer.fit_transform(sentences)
# ----> 3 print(X.toarray())
#
# ~\PycharmProjects\NLP_Lab01\venv\lib\site-packages\numpy\core\arrayprint.py in _array_str_implementation(a, max_line_width, precision, suppress_small, array2string)
#    1527         return _guarded_str(np.ndarray.__getitem__(a, ()))
#    1528
# -> 1529     return array2string(a, max_line_width, precision, suppress_small, ' ', "")
#    1530
#    1531
#
# ~\PycharmProjects\NLP_Lab01\venv\lib\site-packages\numpy\core\arrayprint.py in array2string(a, max_line_width, precision, suppress_small, separator, prefix, style, formatter, threshold, edgeitems, sign, floatmode, suffix, **kwarg)
#     698         return "[]"
#     699
# --> 700     return _array2string(a, options, separator, prefix)
#     701
#     702
#
# ~\PycharmProjects\NLP_Lab01\venv\lib\site-packages\numpy\core\arrayprint.py in wrapper(self, *args, **kwargs)
#     470             repr_running.add(key)
#     471             try:
# --> 472                 return f(self, *args, **kwargs)
#     473             finally:
#     474                 repr_running.discard(key)
#
# ~\PycharmProjects\NLP_Lab01\venv\lib\site-packages\numpy\core\arrayprint.py in _array2string(a, options, separator, prefix)
#     505     lst = _formatArray(a, format_function, options['linewidth'],
#     506                        next_line_prefix, separator, options['edgeitems'],
# --> 507                        summary_insert, options['legacy'])
#     508     return lst
#     509
#
# ~\PycharmProjects\NLP_Lab01\venv\lib\site-packages\numpy\core\arrayprint.py in _formatArray(a, format_function, line_width, next_line_prefix, separator, edge_items, summary_insert, legacy)
#     826         return recurser(index=(),
#     827                         hanging_indent=next_line_prefix,
# --> 828                         curr_width=line_width)
#     829     finally:
#     830         # recursive closures have a cyclic reference to themselves, which
#
# ~\PycharmProjects\NLP_Lab01\venv\lib\site-packages\numpy\core\arrayprint.py in recurser(index, hanging_indent, curr_width)
#     813                 nested = recurser(index + (-i,), next_hanging_indent,
#     814                                   next_width)
# --> 815                 s += hanging_indent + nested + line_sep
#     816
#     817             nested = recurser(index + (-1,), next_hanging_indent, next_width)
#
# KeyboardInterrupt:

# %%
import re
import string
import spacy

# %%
import nltk
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\elena\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
from nltk.corpus import words

# %%
wordlist = set(words.words())
type(words.words())
# Out:
# list

# %%
pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.0.0/en_core_web_sm-2.0.0.tar.gz --no-deps
# Out:
# Collecting https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.0.0/en_core_web_sm-2.0.0.tar.gz
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.0.0/en_core_web_sm-2.0.0.tar.gz (37.4MB)
# Requirement already satisfied (use --upgrade to upgrade): en-core-web-sm==2.0.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.0.0/en_core_web_sm-2.0.0.tar.gz in c:\users\elena\pycharmprojects\nlp_lab01\venv\lib\site-packages
# WARNING: You are using pip version 19.2.3, however version 19.3.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
wordlist
# Out:
# {'microsclerum',
#  'pronotal',
#  'spindleage',
#  'anticomplement',
#  'pseudobenthos',
#  'energumenon',
#  'femorocaudal',
#  'suffusive',
#  'omphalospinous',
#  'prompt',
#  'Kolkka',
#  'agonistics',
#  'cuartilla',
#  'naggle',
#  'spongoblastic',
#  'interdenominational',
#  'exhibitioner',
#  'metaluminic',
#  'Macaglia',
#  'fissiped',
#  'toluide',
#  'sclim',
#  'bolsterer',
#  'fittily',
#  'unresemblant',
#  'tragal',
#  'nonowner',
#  'zoom',
#  'pretransmit',
#  'psychrophyte',
#  'roborean',
#  'awater',
#  'overlander',
#  'lucratively',
#  'farrier',
#  'pipette',
#  'phylacteried',
#  'Typhonian',
#  'underrealm',
#  'disinterment',
#  'ecology',
#  'thenness',
#  'presbyophrenia',
#  'undefinable',
#  'semidelight',
#  'capsulolenticular',
#  'bronchotyphoid',
#  'bowker',
#  'olenidian',
#  'codictatorship',
#  'boke',
#  'bribemonger',
#  'quintus',
#  'scathelessly',
#  'complacent',
#  'contentedly',
#  'hike',
#  'picketeer',
#  'ast',
#  'saprostomous',
#  'aphetic',
#  'basiarachnoiditis',
#  'incourteous',
#  'polydisperse',
#  'perichoresis',
#  'blenching',
#  'epicist',
#  'genealogically',
#  'undisturbingly',
#  'salinometer',
#  'hydroscopical',
#  'enrapturer',
#  'prediminishment',
#  'Acoela',
#  'unresistedness',
#  'inconsonant',
#  'acrose',
#  'unslagged',
#  'caress',
#  'intercurrent',
#  'level',
#  'Neoplatonic',
#  'overpainfulness',
#  'ungrieve',
#  'rebluff',
#  'zymotic',
#  'chemicoengineering',
#  'lek',
#  'bibliophilistic',
#  'apyrexy',
#  'resolidify',
#  'archaist',
#  'alloxanic',
#  'resonatory',
#  'variolovaccine',
#  'lotic',
#  'crossbowman',
#  'elfwife',
#  'velociously',
#  'entodermic',
#  'subcingulum',
#  'trillionize',
#  'voyager',
#  'overdeliberation',
#  'feminie',
#  'acolyte',
#  'neogamous',
#  'plauenite',
#  'unsobriety',
#  'chloropicrin',
#  'bubblingly',
#  'dividedness',
#  'kusimansel',
#  'Morocco',
#  'fingersmith',
#  'Afrasia',
#  'regimentary',
#  'Echinidea',
#  'adenoneural',
#  'unexpectorated',
#  'alure',
#  'blain',
#  'bryonin',
#  'throughput',
#  'siscowet',
#  'dermoneurosis',
#  'revivability',
#  'inelegantly',
#  'Saprolegniaceae',
#  'sifflot',
#  'amaranthine',
#  'sowbread',
#  'laryngotyphoid',
#  'internode',
#  'Liliaceae',
#  'muddify',
#  'pantologic',
#  'hydroxamic',
#  'alethoscope',
#  'Podophyllaceae',
#  'ungull',
#  'arrogative',
#  'nebulous',
#  'downless',
#  'crawberry',
#  'glucinum',
#  'Egyptianize',
#  'messing',
#  'overwatch',
#  'gorgeous',
#  'amblyaphia',
#  'ensuance',
#  'hypercatalexis',
#  'antipriming',
#  'reconstructor',
#  'senega',
#  'slipshoe',
#  'unpeel',
#  'yttric',
#  'cam',
#  'impropriator',
#  'pidjajap',
#  'vowelist',
#  'bioral',
#  'puberal',
#  'reconciliatory',
#  'sahh',
#  'truculency',
#  'severedly',
#  'spinales',
#  'tailless',
#  'bilicyanin',
#  'moorpan',
#  'Ancylostoma',
#  'counterstruggle',
#  'socionomic',
#  'dowerless',
#  'ornithologist',
#  'atrophoderma',
#  'distomatous',
#  'organing',
#  'phenethyl',
#  'irisroot',
#  'pseudarachnidan',
#  'calcemia',
#  'conative',
#  'macrocephalia',
#  'sumple',
#  'trigamous',
#  'cautelously',
#  'complementary',
#  'antinepotic',
#  'hobblebush',
#  'cleamer',
#  'mishmee',
#  'thrombolymphangitis',
#  'xanthopsia',
#  'unindebtedness',
#  'decadentism',
#  'pronubial',
#  'lingual',
#  'quinquevalent',
#  'unpavilioned',
#  'scaly',
#  'Mosaic',
#  'abutter',
#  'fragmentist',
#  'sphincteric',
#  'knobby',
#  'angiogeny',
#  'coembody',
#  'Marxism',
#  'onomatologist',
#  'irreproductive',
#  'precontrolled',
#  'unraffled',
#  'sufferableness',
#  'lichenologic',
#  'odontoclast',
#  'reseize',
#  'Homalopterous',
#  'trocar',
#  'undercharged',
#  'hogweed',
#  'untransitable',
#  'semiplume',
#  'ulna',
#  'anetiological',
#  'oyster',
#  'Anaces',
#  'floatboard',
#  'mirabilite',
#  'rockward',
#  'uncheering',
#  'autoecious',
#  'laughingstock',
#  'pecuniosity',
#  'tsaritza',
#  'celidographer',
#  'congratulatory',
#  'ectocarpic',
#  'zeugmatic',
#  'sulfamerazine',
#  'dichlorhydrin',
#  'horrorful',
#  'disenfranchisement',
#  'corymbiate',
#  'Sparganiaceae',
#  'absonant',
#  'overlavishly',
#  'cytodiagnosis',
#  'spheration',
#  'thitherto',
#  'plaguily',
#  'Eddy',
#  'robustness',
#  'tragicality',
#  'balinghasay',
#  'hennish',
#  'Kuhnia',
#  'Tlapallan',
#  'polydipsia',
#  'deductively',
#  'uredema',
#  'introspectionist',
#  'hideless',
#  'unembayed',
#  'thermogenesis',
#  'crowingly',
#  'Xanthochroi',
#  'canzonet',
#  'sufferably',
#  'flute',
#  'polishedness',
#  'sporid',
#  'blunge',
#  'dosa',
#  'dredging',
#  'jusquaboutisme',
#  'misemphasis',
#  'overdoubt',
#  'periligamentous',
#  'endophytically',
#  'turbinate',
#  'Croomia',
#  'optionor',
#  'psomophagist',
#  'haughtonite',
#  'disruption',
#  'blowcock',
#  'charioteership',
#  'overchoke',
#  'overcrowdedness',
#  'penholder',
#  'difficult',
#  'metroperitonitis',
#  'sprogue',
#  'cholochrome',
#  'Camorrist',
#  'cursoriness',
#  'ternar',
#  'ensanguine',
#  'sewered',
#  'jungle',
#  'prolocutor',
#  'reproductiveness',
#  'extricate',
#  'nondemobilization',
#  'conquerment',
#  'tenectomy',
#  'antilobium',
#  'congregationist',
#  'legible',
#  'nib',
#  'chokidar',
#  'drawlink',
#  'overnimble',
#  'rhumb',
#  'ultranegligent',
#  'observancy',
#  'ipsilateral',
#  'biannually',
#  'macedoine',
#  'postfoveal',
#  'Prorhipidoglossomorpha',
#  'planetaria',
#  'christcross',
#  'handcraft',
#  'soggy',
#  'biarcuate',
#  'professorling',
#  'occipitoscapular',
#  'brandreth',
#  'theorematically',
#  'roit',
#  'landgravate',
#  'officiant',
#  'Chera',
#  'exacerbescent',
#  'tu',
#  'processor',
#  'breastweed',
#  'darkful',
#  'dicodeine',
#  'tored',
#  'enunciatory',
#  'tarsochiloplasty',
#  'mockground',
#  'authorial',
#  'antlerless',
#  'telophragma',
#  'protrusiveness',
#  'mononuclear',
#  'suprachorioidea',
#  'hypogeocarpous',
#  'unfletched',
#  'eductor',
#  'Fulfulde',
#  'malignant',
#  'reducibly',
#  'inviting',
#  'mushy',
#  'educationist',
#  'expunge',
#  'physoclistic',
#  'saffroned',
#  'upcoast',
#  'Ilysanthes',
#  'parergon',
#  'manganbrucite',
#  'nonplastic',
#  'unproscribed',
#  'egesta',
#  'flapperhood',
#  'Chautauqua',
#  'handballer',
#  'secretum',
#  'euchroic',
#  'womanhearted',
#  'taproom',
#  'agitatedly',
#  'hollowness',
#  'appropriable',
#  'anthropophuism',
#  'drawtube',
#  'arcanite',
#  'Eoghanacht',
#  'spectrophone',
#  'Negrito',
#  'teleologist',
#  'Alytes',
#  'whistlerism',
#  'embalmer',
#  'penner',
#  'resinifluous',
#  'semiproven',
#  'Canaanite',
#  'suppurate',
#  'chloramphenicol',
#  'superunit',
#  'unexistence',
#  'anorthic',
#  'mesosporic',
#  'annexionist',
#  'uncountable',
#  'chold',
#  'pryproof',
#  'sarlyk',
#  'tanbur',
#  'flow',
#  'paca',
#  'spiculigenous',
#  'unibracteate',
#  'your',
#  'jettiness',
#  'monumentary',
#  'hoplonemertean',
#  'purwannah',
#  'blackbush',
#  'nondefendant',
#  'nonobservant',
#  'impacted',
#  'meizoseismic',
#  'relatable',
#  'madapollam',
#  'sorcerous',
#  'sacrococcygean',
#  'neuropsychiatry',
#  'resolve',
#  'leptodermatous',
#  'radiohumeral',
#  'scarabaeiform',
#  'Dioctophyme',
#  'orthophonic',
#  'cellularity',
#  'circulate',
#  'megalopic',
#  'upwound',
#  'vaginomycosis',
#  'unrustling',
#  'wastingness',
#  'Chersydridae',
#  'gossiphood',
#  'hyperfocal',
#  'mazeful',
#  'Nematognathi',
#  'ravage',
#  'slopshop',
#  'tesserarian',
#  'lechuguilla',
#  'throng',
#  'abbotship',
#  'unforfeitable',
#  'morphallaxis',
#  'taintor',
#  'magicianship',
#  'swelter',
#  'grist',
#  'endosteum',
#  'precompilation',
#  'tibiotarsal',
#  'Yauapery',
#  'duplicature',
#  'unprecedentedly',
#  'enterochlorophyll',
#  'psammology',
#  'cuprodescloizite',
#  'unshelling',
#  'plausibleness',
#  'ultrasubtle',
#  'parrotism',
#  'scalenus',
#  'recordation',
#  'siphonognathous',
#  'unclay',
#  'asonant',
#  'anthropogeographical',
#  'nephrostoma',
#  'unwayed',
#  'Cotingidae',
#  'autonegation',
#  'knarry',
#  'vibrissal',
#  'foulmouthed',
#  'killcu',
#  'Peratae',
#  'unrinsed',
#  'anarchize',
#  'Exoascus',
#  'refractometry',
#  'couma',
#  'cowroid',
#  'codification',
#  'gersdorffite',
#  'hanksite',
#  'docken',
#  'leapt',
#  'pinguiferous',
#  'moringaceous',
#  'Don',
#  'fortuity',
#  'gamesomeness',
#  'satient',
#  'exhauster',
#  'incursion',
#  'Lenape',
#  'stoff',
#  'transitoriness',
#  'fibber',
#  'branchireme',
#  'redoom',
#  'liwan',
#  'righten',
#  'cardin',
#  'odontoid',
#  'chainage',
#  'delightsome',
#  'tillage',
#  'womanization',
#  'Janiculum',
#  'tokopat',
#  'invitable',
#  'recirculate',
#  'submarginal',
#  'sincipital',
#  'appleringy',
#  'intercondenser',
#  'godsonship',
#  'leucomatous',
#  'assishness',
#  'violence',
#  'delinquent',
#  'perty',
#  'comenic',
#  'sensibilitous',
#  'urologic',
#  'whalehead',
#  'sorrowingly',
#  'aduncous',
#  'Tetragonia',
#  'semisupination',
#  'interlibel',
#  'Strepsiptera',
#  'skibslast',
#  'vaccinate',
#  'pierceable',
#  'hame',
#  'unaccordable',
#  'inobnoxious',
#  'liang',
#  'Ariel',
#  'legrope',
#  'psammologist',
#  'upstruggle',
#  'semiobscurity',
#  'homozygous',
#  'cholla',
#  'sericeotomentose',
#  'Madrasi',
#  'Messiahship',
#  'fosterling',
#  'disturber',
#  'rosarian',
#  'colyum',
#  'nonvertically',
#  'monocrotic',
#  'subjoint',
#  'tickseeded',
#  'bearbind',
#  'culmination',
#  'impeticos',
#  'snubbiness',
#  'stringpiece',
#  'strigine',
#  'folium',
#  'theezan',
#  'inket',
#  'foody',
#  'boviform',
#  'hygrophanous',
#  'aldehydic',
#  'myxopapilloma',
#  'fight',
#  'jibbah',
#  'unsyncopated',
#  'perenniality',
#  'immutation',
#  'misbecome',
#  'norm',
#  'remunerativeness',
#  'syssitia',
#  'unfused',
#  'octanaphthene',
#  'Zuluize',
#  'engulfment',
#  'cogroad',
#  'quindecad',
#  'entremets',
#  'pregratification',
#  'recensor',
#  'sublenticular',
#  'oversubtly',
#  'ophthalmorrhexis',
#  'chimera',
#  'intarsiate',
#  'peart',
#  'hypotrophy',
#  'discoursively',
#  'nucleolus',
#  'sclerized',
#  'bespeckle',
#  'certainly',
#  'uphurl',
#  'productid',
#  'dreamlit',
#  'lesion',
#  'melano',
#  'carpal',
#  'resoil',
#  'jasminewood',
#  'starting',
#  'scleritic',
#  'unattracted',
#  'inaugurer',
#  'songcraft',
#  'antilethargic',
#  'synenergistical',
#  'Sisseton',
#  'protective',
#  'underfur',
#  'Tappertitian',
#  'tired',
#  'subareolet',
#  'climacteric',
#  'upheal',
#  'myohematin',
#  'schizocarpous',
#  'osteochondrous',
#  'peele',
#  'thymicolymphatic',
#  'glovemaker',
#  'gainfully',
#  'chickstone',
#  'horsiness',
#  'diplopod',
#  'wassail',
#  'blazoning',
#  'Yamel',
#  'masonry',
#  'Palearctic',
#  'accessively',
#  'hoseman',
#  'nig',
#  'guacimo',
#  'periodograph',
#  'townland',
#  'anywhere',
#  'culgee',
#  'Austin',
#  'quoit',
#  'raptril',
#  'Menispermum',
#  'fluency',
#  'evirate',
#  'kinesiologic',
#  'renickel',
#  'fairness',
#  'reminiscer',
#  'cremation',
#  'contribute',
#  'Scopularia',
#  'anophyte',
#  'preconcentrated',
#  'schalmey',
#  'unproportional',
#  'osteogenous',
#  'stenotypic',
#  'conservate',
#  'circumpacific',
#  'curiescopy',
#  'omniformal',
#  'distender',
#  'progenitor',
#  'theriaca',
#  'nonnutrient',
#  'anaxon',
#  'bosky',
#  'antinosarian',
#  'diplomatize',
#  'capitation',
#  'discerption',
#  'strikeboat',
#  'taillike',
#  'distempered',
#  'jabiru',
#  'incoherency',
#  'mutoscope',
#  'rabiform',
#  'unhazarding',
#  'interactional',
#  'multiscience',
#  'unroped',
#  'Plautus',
#  'spondylic',
#  'brassbounder',
#  'azoxonium',
#  'heartgrief',
#  'slowbelly',
#  'nontemporal',
#  'platinochloric',
#  'chartless',
#  'unroller',
#  'bacterioscopical',
#  'slidable',
#  'Harold',
#  'archthief',
#  'cocitizen',
#  'headrest',
#  'byway',
#  'catapultic',
#  'disprivilege',
#  'plasmoptysis',
#  'sanitation',
#  'matterative',
#  'toolholding',
#  'broose',
#  'unavailful',
#  'cardiomelanosis',
#  'Wren',
#  'scission',
#  'hypertoxic',
#  'chiliast',
#  'gallinipper',
#  'unvocalized',
#  'forwoden',
#  'noncreditor',
#  'mermithogyne',
#  'trashiness',
#  'granjeno',
#  'footpad',
#  'secque',
#  'Trochilus',
#  'Morisco',
#  'akimbo',
#  'unwatched',
#  'hexaploidy',
#  'nymphlike',
#  'tyrant',
#  'thimbleberry',
#  'unrip',
#  'presenter',
#  'unexcoriated',
#  'falsify',
#  'amicronucleate',
#  'aphanite',
#  'electrooptical',
#  'cheatrie',
#  'preoperative',
#  'reviolate',
#  'proabsolutism',
#  'billy',
#  'Sphaeropsis',
#  'autotriploidy',
#  'doctress',
#  'relock',
#  'vibrantly',
#  'pedimented',
#  'Graptolithina',
#  'contractibility',
#  'helminthoid',
#  'multitudinously',
#  'potentate',
#  'hypha',
#  'hemihypalgesia',
#  'courtly',
#  'curby',
#  'commandless',
#  'Guttiferales',
#  'overaccurate',
#  'Callitriche',
#  'disposure',
#  'leptoprosopy',
#  'overcheap',
#  'sensualism',
#  'unflippant',
#  'Titanically',
#  'ketuba',
#  'corticifugally',
#  'Pecopteris',
#  'Pennatulacea',
#  'bleater',
#  'impingence',
#  'abscessroot',
#  'pallholder',
#  'thornlike',
#  'Eremochaeta',
#  'strepitation',
#  'veldschoen',
#  'thaumasite',
#  'dysplastic',
#  'miffiness',
#  'Sextant',
#  'terremotive',
#  'Sinophilism',
#  'colpoperineoplasty',
#  'aposia',
#  'eclipse',
#  'wingle',
#  'hostageship',
#  'veinstuff',
#  'fabulously',
#  'sympathize',
#  'phanatron',
#  'vicinal',
#  'coheirship',
#  'necrophilic',
#  'scripula',
#  'hysteretically',
#  'tribrachial',
#  'unnegotiableness',
#  'abominably',
#  'phenomenal',
#  'Geheimrat',
#  'Phalangida',
#  'symphylous',
#  'adstipulation',
#  'basifacial',
#  'ostreiculture',
#  'photaesthetic',
#  'scirtopod',
#  'anoil',
#  'nickelage',
#  'finitesimal',
#  'unadmire',
#  'handworkman',
#  'empress',
#  'demisangue',
#  'jemmy',
#  'guardship',
#  'overbrowse',
#  'zinsang',
#  'pneumonoenteritis',
#  'fairfieldite',
#  'aluminide',
#  'expirant',
#  'hydroferricyanic',
#  'mechanize',
#  'untoured',
#  'Nethinim',
#  'mouthless',
#  'Pleione',
#  'fireboat',
#  'osteostomous',
#  'pseudoperiodic',
#  'sexradiate',
#  'plowing',
#  'sourishness',
#  'sternocleidomastoid',
#  'fess',
#  'smilelessly',
#  'careless',
#  'carfare',
#  'linon',
#  'mastigophoric',
#  'bergaptene',
#  'keyage',
#  'Sadducee',
#  'ultrasevere',
#  'urostealith',
#  'missish',
#  'siris',
#  'unhewed',
#  'conatus',
#  'frosty',
#  'wrinklet',
#  'downward',
#  'trinitration',
#  'encircle',
#  'folia',
#  'ungently',
#  'concurso',
#  'bestill',
#  'electrocardiograph',
#  'plowfish',
#  'chrysophan',
#  'anthropical',
#  'tervee',
#  'perirectal',
#  'evangelize',
#  'pewfellow',
#  'conservancy',
#  'pseudostereoscope',
#  'countertheme',
#  'monodactylism',
#  'martinetism',
#  'unvitalness',
#  'pyrosomoid',
#  'Opiliaceae',
#  'foremean',
#  'potestal',
#  'annulation',
#  'arkose',
#  'Gothamite',
#  'troctolite',
#  'sorrowless',
#  'junkman',
#  'vansire',
#  'analepsy',
#  'gumbotil',
#  'sclaw',
#  'monodize',
#  'gelotometer',
#  'stroup',
#  'creatophagous',
#  'aedicula',
#  'talkable',
#  'disprobative',
#  'Targumical',
#  'unblasted',
#  'violability',
#  'Lepidosirenidae',
#  'climacterically',
#  'Shardana',
#  'suffruticous',
#  'foiler',
#  'laterostigmatic',
#  'expectantly',
#  'inapparent',
#  'shinza',
#  'dispericraniate',
#  'diaplexal',
#  'unclawed',
#  'outrogue',
#  'doubtous',
#  'diolefinic',
#  'Mimi',
#  'wareless',
#  'makership',
#  'upgrade',
#  'heathenishness',
#  'protyle',
#  'volitional',
#  'nephewship',
#  'iceless',
#  'ignorantness',
#  'crockery',
#  'sneeringly',
#  'sotnik',
#  'unchivalrously',
#  'decomposability',
#  'stackman',
#  'agoniada',
#  'misbaptize',
#  'engrossingly',
#  'zygosis',
#  'magnetoprinter',
#  'Semitism',
#  'beshade',
#  'pellagragenic',
#  'unbracedness',
#  'circuiter',
#  'atheisticalness',
#  'immaculateness',
#  'imitant',
#  'postvide',
#  'leaser',
#  'migratory',
#  'cloudless',
#  'begreen',
#  'femineity',
#  'Hitoshi',
#  'coreveler',
#  'Cycadofilices',
#  'diswood',
#  'Ovaherero',
#  'Triarthrus',
#  'lonesomeness',
#  'restitutive',
#  'citrine',
#  'rhagionid',
#  'blizz',
#  'Strad',
#  'villatic',
#  'semimystic',
#  'anakinetic',
#  'nonresidence',
#  'deploitation',
#  'sclerotal',
#  'swire',
#  'executry',
#  'inalterably',
#  'unca',
#  'bigamous',
#  'boder',
#  'roentgenotherapy',
#  'scamler',
#  'matterate',
#  'unwarranted',
#  'Lahuli',
#  'oriflamme',
#  ...}
